# %% [markdown]
# <a href="https://colab.research.google.com/github/reghudevi-coder/Reghudevi-craving-codes/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("/content/Dataset222.csv")
print("Data loaded Successfully")
# Out:
# Data loaded Successfully

# %%
df.head()
# Out:
#    Unnamed: 0 FirstName LastName  StartDate ExitDate                    Title  \
# 0           0     Uriah  Bridges  20-Sep-19      NaN  Production Technician I
# 1           1     Paula    Small  11-Feb-23      NaN  Production Technician I
# 2           2    Edward     Buck  10-Dec-18      NaN       Area Sales Manager
# 3           3   Michael  Riordan  21-Jun-21      NaN       Area Sales Manager
# 4           4   Jasmine    Onque  29-Jun-19      NaN       Area Sales Manager
#
#         Supervisor                        ADEmail BusinessUnit EmployeeStatus  \
# 0     Peter Oneill    uriah.bridges@bilearner.com         CCDR         Active
# 1  Renee Mccormick      paula.small@bilearner.com           EW         Active
# 2   Crystal Walker      edward.buck@bilearner.com           PL         Active
# 3   Rebekah Wright  michael.riordan@bilearner.com         CCDR         Active
# 4        Jason Kim    jasmine.onque@bilearner.com          TNS         Active
#
# ...

# %%
df.shape
# Out:
# (3150, 39)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3150 entries, 0 to 3149
# Data columns (total 39 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  3150 non-null   int64
#  1   FirstName                   3150 non-null   object
#  2   LastName                    3150 non-null   object
#  3   StartDate                   3150 non-null   object
#  4   ExitDate                    1606 non-null   object
#  5   Title                       3150 non-null   object
#  6   Supervisor                  3150 non-null   object
#  7   ADEmail                     3150 non-null   object
#  8   BusinessUnit                3150 non-null   object
#  9   EmployeeStatus              3150 non-null   object
#  10  EmployeeType                3150 non-null   object
#  11  PayZone                     3150 non-null   object
#  12  EmployeeClassificationType  3150 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'FirstName', 'LastName', 'StartDate', 'ExitDate', 'Title',
#        'Supervisor', 'ADEmail', 'BusinessUnit', 'EmployeeStatus',
#        'EmployeeType', 'PayZone', 'EmployeeClassificationType',
#        'TerminationType', 'TerminationDescription', 'DepartmentType',
#        'Division', 'DOB', 'State', 'JobFunctionDescription', 'GenderCode',
#        'LocationCode', 'RaceDesc', 'MaritalDesc', 'Performance Score',
#        'Current Employee Rating', 'Employee ID', 'Survey Date',
#        'Engagement Score', 'Satisfaction Score', 'Work-Life Balance Score',
#        'Training Date', 'Training Program Name', 'Training Type',
#        'Training Outcome', 'Location', 'Trainer', 'Training Duration(Days)',
#        'Training Cost'],
#       dtype='object')

# %%
df.describe()
# Out:
#         Unnamed: 0  LocationCode  Current Employee Rating  Employee ID  \
# count  3150.000000   3150.000000              3150.000000  3150.000000
# mean   1495.748254  45155.332698                 2.968254  2502.748254
# std     867.007861  30019.418852                 1.020717   866.241991
# min       0.000000   1013.000000                 1.000000  1001.000000
# 25%     746.000000  17616.500000                 2.000000  1750.250000
# 50%    1495.500000  44455.500000                 3.000000  2504.500000
# 75%    2246.750000  71713.250000                 3.000000  3254.750000
# max    2999.000000  98052.000000                 5.000000  4000.000000
#
#        Engagement Score  Satisfaction Score  Work-Life Balance Score  \
# count       3150.000000         3150.000000              3150.000000
# mean           2.943492            3.021270                 2.992381
# std            1.430727            1.407413                 1.409244
# ...

# %%
df.select_dtypes(include='object').describe()
# Out:
#        FirstName LastName  StartDate   ExitDate                    Title  \
# count       3150     3150       3150       1606                     3150
# unique      1597     1137       1496        820                       32
# top       Harley  Preston  18-Jul-19  21-Jul-23  Production Technician I
# freq          10       12          8         10                     1380
#
#          Supervisor                      ADEmail BusinessUnit EmployeeStatus  \
# count          3150                         3150         3150           3150
# unique         2952                         2998           10              5
# top     David Moore  hadley.benson@bilearner.com          SVG         Active
# freq              3                            2          327           2583
#
#        EmployeeType  ... RaceDesc MaritalDesc Performance Score Survey Date  \
# count          3150  ...     3150        3150              3150        3150
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                       0
# FirstName                        0
# LastName                         0
# StartDate                        0
# ExitDate                      1544
# Title                            0
# Supervisor                       0
# ADEmail                          0
# BusinessUnit                     0
# EmployeeStatus                   0
# EmployeeType                     0
# PayZone                          0
# EmployeeClassificationType       0
# TerminationType                  0
# TerminationDescription        1544
# DepartmentType                   0
# Division                         0
# DOB                              0
# State                            0
# JobFunctionDescription           0
# GenderCode                       0
# LocationCode                     0
# RaceDesc                         0
# MaritalDesc                      0
# Performance Score                0
# Current Employee Rating          0
# Employee ID                      0
# ...

# %%
df.clean=df.copy()
# Out:
# /tmp/ipython-input-3337392917.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.clean=df.copy()

# %%
df.clean.isnull().sum()
# Out:
# Unnamed: 0                       0
# FirstName                        0
# LastName                         0
# StartDate                        0
# ExitDate                      1544
# Title                            0
# Supervisor                       0
# ADEmail                          0
# BusinessUnit                     0
# EmployeeStatus                   0
# EmployeeType                     0
# PayZone                          0
# EmployeeClassificationType       0
# TerminationType                  0
# TerminationDescription        1544
# DepartmentType                   0
# Division                         0
# DOB                              0
# State                            0
# JobFunctionDescription           0
# GenderCode                       0
# LocationCode                     0
# RaceDesc                         0
# MaritalDesc                      0
# Performance Score                0
# Current Employee Rating          0
# Employee ID                      0
# ...

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# Unnamed: 0                     0.000000
# FirstName                      0.000000
# LastName                       0.000000
# StartDate                      0.000000
# ExitDate                      49.015873
# Title                          0.000000
# Supervisor                     0.000000
# ADEmail                        0.000000
# BusinessUnit                   0.000000
# EmployeeStatus                 0.000000
# EmployeeType                   0.000000
# PayZone                        0.000000
# EmployeeClassificationType     0.000000
# TerminationType                0.000000
# TerminationDescription        49.015873
# DepartmentType                 0.000000
# Division                       0.000000
# DOB                            0.000000
# State                          0.000000
# JobFunctionDescription         0.000000
# GenderCode                     0.000000
# LocationCode                   0.000000
# RaceDesc                       0.000000
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(150)

# %%
df.describe(include="object")
# Out:
#        FirstName LastName  StartDate   ExitDate                    Title  \
# count       3150     3150       3150       1606                     3150
# unique      1597     1137       1496        820                       32
# top       Harley  Preston  18-Jul-19  21-Jul-23  Production Technician I
# freq          10       12          8         10                     1380
#
#          Supervisor                      ADEmail BusinessUnit EmployeeStatus  \
# count          3150                         3150         3150           3150
# unique         2952                         2998           10              5
# top     David Moore  hadley.benson@bilearner.com          SVG         Active
# freq              3                            2          327           2583
#
#        EmployeeType  ... RaceDesc MaritalDesc Performance Score Survey Date  \
# count          3150  ...     3150        3150              3150        3150
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                       0
# FirstName                        0
# LastName                         0
# StartDate                        0
# ExitDate                      1544
# Title                            0
# Supervisor                       0
# ADEmail                          0
# BusinessUnit                     0
# EmployeeStatus                   0
# EmployeeType                     0
# PayZone                          0
# EmployeeClassificationType       0
# TerminationType                  0
# TerminationDescription        1544
# DepartmentType                   0
# Division                         0
# DOB                              0
# State                            0
# JobFunctionDescription           0
# GenderCode                       0
# LocationCode                     0
# RaceDesc                         0
# MaritalDesc                      0
# Performance Score                0
# Current Employee Rating          0
# Employee ID                      0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(150)

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3000 entries, 0 to 2999
# Data columns (total 39 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  3000 non-null   int64
#  1   FirstName                   3000 non-null   object
#  2   LastName                    3000 non-null   object
#  3   StartDate                   3000 non-null   object
#  4   ExitDate                    1533 non-null   object
#  5   Title                       3000 non-null   object
#  6   Supervisor                  3000 non-null   object
#  7   ADEmail                     3000 non-null   object
#  8   BusinessUnit                3000 non-null   object
#  9   EmployeeStatus              3000 non-null   object
#  10  EmployeeType                3000 non-null   object
#  11  PayZone                     3000 non-null   object
#  12  EmployeeClassificationType  3000 non-null   object
# ...

# %%
df.to_excel("Cleaned_final.xlsx", index=False)

# %%
df=pd.read_excel("/content/Cleaned_final.xlsx")
print("Data loaded")
# Out:
# Data loaded

# %%
df["Engagement Score"].value_counts()
# Out:
# Engagement Score
# 1    660
# 2    613
# 5    584
# 4    584
# 3    559
# Name: count, dtype: int64

# %%
df['Employee ID'].nunique()
# Out:
# 3000

# %%
df['DepartmentType'].value_counts()
# Out:
# DepartmentType
# Production              2020
# IT/IS                    430
# Sales                    331
# Software Engineering     115
# Admin Offices             80
# Executive Office          24
# Name: count, dtype: int64

# %%
df['Current Employee Rating'].value_counts()
# Out:
# Current Employee Rating
# 3    1530
# 2     510
# 4     419
# 1     271
# 5     270
# Name: count, dtype: int64

# %%
plt.hist(df['Current Employee Rating'])
plt.title("Employee Rating Distribution")
plt.show()

# %%
df['Engagement Score'].describe()
# Out:
# count    3000.000000
# mean        2.939667
# std         1.433426
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         5.000000
# Name: Engagement Score, dtype: float64

# %%
plt.hist(df["Engagement Score"])
plt.title("Engagement Score Distribution")
plt.xlabel("Score")
plt.ylabel("Count")
plt.show()

# %%
df["Satisfaction Score"].describe()
# Out:
# /usr/local/lib/python3.12/dist-packages/IPython/core/displayhook.py:275: UserWarning: Output cache limit (currently 1000 entries) hit.
# Flushing oldest 200 entries.
#   warn('Output cache limit (currently {sz} entries) hit.\n'
# count    3000.000000
# mean        3.022000
# std         1.408845
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         5.000000
# Name: Satisfaction Score, dtype: float64

# %%
plt.hist(df["Satisfaction Score"])
plt.title ("Satisfaction Score Distribution")
plt.xlabel("Score")
plt.ylabel("Count")
plt.show()

# %%
df['ExitDate'].isnull().sum()
# Out:
# np.int64(1467)

# %%
df['Training Program Name'].value_counts().head()
# Out:
# Training Program Name
# Communication Skills      673
# Project Management        609
# Technical Skills          579
# Leadership Development    574
# Customer Service          565
# Name: count, dtype: int64

# %%
df['Training Cost'].describe()
# Out:
# count    3000.000000
# mean      558.628697
# std       263.217698
# min       100.040000
# 25%       327.587500
# 50%       572.125000
# 75%       786.987500
# max       999.970000
# Name: Training Cost, dtype: float64

# %%
plt.boxplot(df['Training Cost'])
plt.title("Training Cost Distribution")
plt.show()

# %%
df['Employee Status']=df['ExitDate'].apply(lambda x: "Active" if pd.isnull(x) else "Exited")

# %%
df.groupby("Employee Status")["Current Employee Rating"].mean()
# Out:
# Employee Status
# Active    2.961145
# Exited    2.976517
# Name: Current Employee Rating, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.barplot(x="Employee Status", y="Current Employee Rating", data=df)
plt.title("Employee Status vs Performance Rating")
plt.show()

# %%
plt.scatter(df["Engagement Score"], df["Satisfaction Score"])
plt.xlabel("Engagement Score")
plt.ylabel("Satisfaction Score")
plt.title("Engagement vs Satisfaction")
plt.show()

# %%
sns.boxplot(x='Training Outcome',y='Engagement Score',data=df)
plt.title("Training Outcome vs Engagement Score")
plt.show()

# %%
sns.boxplot(x="Training Outcome",y="Training Cost",data=df)
plt.title("Training Cost vs Training Outcome")
plt.show()

# %%
df.groupby("DepartmentType")["Engagement Score"].mean().sort_values(ascending=False)
# Out:
# DepartmentType
# Executive Office        3.375000
# IT/IS                   3.025581
# Sales                   2.990937
# Software Engineering    2.973913
# Admin Offices           2.925000
# Production              2.906436
# Name: Engagement Score, dtype: float64

# %%
sns.boxplot(x="DepartmentType",y="Engagement Score", data=df)
plt.xticks(rotation=90)
plt.title("DepartmentType vs Engagement Score")
plt.show()

# %%
sns.scatterplot(x='Engagement Score',y='Satisfaction Score',hue='Current Employee Rating',data=df)
plt.title("Engagement, Satisfaction Score & Performance Rating")
plt.show()

# %%
sns.boxplot(x='Employee Status',y='Engagement Score',hue='Current Employee Rating',data=df)
plt.title("Employee Status, Engagement Score & Rating")
plt.show()

# %%
sns.boxplot(x='Training Outcome',y='Engagement Score',hue='Employee Status',data=df)
plt.title("Training Outcome,Engagement Score & Employee Status")
plt.show()

# %%
plt.hist(df['Engagement Score'])
plt.title("Distribution of Employee Engagement Scores")
plt.xlabel("Engagement Score")
plt.ylabel("Number of Employees")
plt.show()

# %%
plt.hist(df['Satisfaction Score'])
plt.title("Distribution of Employee Satisfaction Scores")
plt.xlabel("Satisfaction Score")
plt.ylabel("Number of Employees")
plt.show()

# %%
plt.scatter(df['Engagement Score'], df['Satisfaction Score'])
plt.xlabel("Engagement Score")
plt.ylabel("Satisfaction Score")
plt.title("Engagement Score vs Satisfaction Score")
plt.show()

# %%
sns.boxplot(
    x='Employee Status',
    y='Current Employee Rating',
    data=df
)
plt.title("Employee Status vs Performance Rating")
plt.show()

# %%
sns.boxplot(
    x='Training Outcome',
    y='Engagement Score',
    data=df
)
plt.title("Training Outcome vs Engagement Score")
plt.show()

# %%
sns.boxplot(x='DepartmentType',y='Engagement Score',data=df)
plt.xticks(rotation=90)
plt.title("Department-wise Engagement Score")
plt.show()

# %%
sns.scatterplot(x='Engagement Score',y='Satisfaction Score',hue='Current Employee Rating',data=df)
plt.title("Engagement, Satisfaction & Performance Rating")
plt.show()
